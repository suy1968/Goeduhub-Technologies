# %% [markdown]
# # SUYASH PRATAP SINGH
#
#
# # Registration ID: GO_STP_6412

# %% [markdown]
# # Import the libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt

# %% [markdown]
# # 1- Load the dataset IMDB.csv

# %%
df = pd.read_csv(r'C:\Users\Admin\Downloads\IMDB-Movie-Data.csv')

# %% [markdown]
# # 2- View the dataset

# %%
#print first five row
df.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
#print last five row
df.tail()
# Out:
#      Rank                   Title                  Genre  \
# 995   996    Secret in Their Eyes    Crime,Drama,Mystery
# 996   997         Hostel: Part II                 Horror
# 997   998  Step Up 2: The Streets    Drama,Music,Romance
# 998   999            Search Party       Adventure,Comedy
# 999  1000              Nine Lives  Comedy,Family,Fantasy
#
#                                            Description          Director  \
# 995  A tight-knit team of rising investigators, alo...         Billy Ray
# 996  Three American college students studying abroa...          Eli Roth
# 997  Romantic sparks occur between two dance studen...        Jon M. Chu
# 998  A pair of friends embark on a mission to reuni...    Scot Armstrong
# 999  A stuffy businessman finds himself trapped ins...  Barry Sonnenfeld
#
#                                                 Actors  Year  \
# 995  Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...  2015
# ...

# %%
#print random five row
df.sample(5)
# Out:
#      Rank            Title                  Genre  \
# 376   377       Black Mass  Biography,Crime,Drama
# 876   877      Warm Bodies  Comedy,Horror,Romance
# 347   348  American Hustle            Crime,Drama
# 371   372  The Maze Runner  Action,Mystery,Sci-Fi
# 524   525            Trust   Crime,Drama,Thriller
#
#                                            Description          Director  \
# 376  The true story of Whitey Bulger, the brother o...      Scott Cooper
# 876  After a highly unusual zombie saves a still-li...   Jonathan Levine
# 347  A con man, Irving Rosenfeld, along with his se...  David O. Russell
# 371  Thomas is deposited in a community of boys aft...          Wes Ball
# 524  A teenage girl is targeted by an online sexual...   David Schwimmer
#
#                                                 Actors  Year  \
# 376  Johnny Depp, Benedict Cumberbatch, Dakota John...  2015
# 876  Nicholas Hoult, Teresa Palmer, John Malkovich,...  2013
# ...

# %% [markdown]
# # 3. Understand some basic information about the dataset and Inspect the dataframe Inspect the dataframe's columns, shapes, variable types etc.

# %%
df.dtypes
# Out:
# Rank                    int64
# Title                  object
# Genre                  object
# Description            object
# Director               object
# Actors                 object
# Year                    int64
# Runtime (Minutes)       int64
# Rating                float64
# Votes                   int64
# Revenue (Millions)    float64
# Metascore             float64
# dtype: object

# %%
df.describe() #Statistical Measures
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# ...

# %% [markdown]
# # Conclusion:- We can see the dataset from 2006 to 2016.The average rating for the movies in this dataset is about 6.7 and the minimum rating is 1.9 and the maximum rating is 9.0 ->The maximum revenue earned by a movie is 936.6 million

# %%
df.info() # basic information of dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
df.columns #check column name
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
df.ndim  #dimension
# Out:
# 2

# %%
df.shape  #shape of dataset
# Out:
# (1000, 12)

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=1000, step=1),
#  Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#         'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#         'Metascore'],
#        dtype='object')]

# %%
#Unique Values
df.nunique()
# Out:
# Rank                  1000
# Title                  999
# Genre                  207
# Description           1000
# Director               644
# Actors                 996
# Year                    11
# Runtime (Minutes)       94
# Rating                  55
# Votes                  997
# Revenue (Millions)     814
# Metascore               84
# dtype: int64

# %% [markdown]
# # 4. Data Selection – Indexing and Slicing

# %%
gen1 = df['Genre']

# %%
df[['Genre']]
# Out:
#                         Genre
# 0     Action,Adventure,Sci-Fi
# 1    Adventure,Mystery,Sci-Fi
# 2             Horror,Thriller
# 3     Animation,Comedy,Family
# 4    Action,Adventure,Fantasy
# ..                        ...
# 995       Crime,Drama,Mystery
# 996                    Horror
# 997       Drama,Music,Romance
# 998          Adventure,Comedy
# 999     Comedy,Family,Fantasy
#
# [1000 rows x 1 columns]

# %%
multiple_cols = df[['Title','Genre','Actors','Director','Rating']]

# %%
multiple_cols
# Out:
#                        Title                     Genre  \
# 0    Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1                 Prometheus  Adventure,Mystery,Sci-Fi
# 2                      Split           Horror,Thriller
# 3                       Sing   Animation,Comedy,Family
# 4              Suicide Squad  Action,Adventure,Fantasy
# ..                       ...                       ...
# 995     Secret in Their Eyes       Crime,Drama,Mystery
# 996          Hostel: Part II                    Horror
# 997   Step Up 2: The Streets       Drama,Music,Romance
# 998             Search Party          Adventure,Comedy
# 999               Nine Lives     Comedy,Family,Fantasy
#
#                                                 Actors              Director  \
# 0    Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...            James Gunn
# 1    Noomi Rapace, Logan Marshall-Green, Michael Fa...          Ridley Scott
# ...

# %%
df.iloc[9:15][['Title','Rating','Revenue (Millions)']]
# Out:
#                                       Title  Rating  Revenue (Millions)
# 9                                Passengers     7.0              100.01
# 10  Fantastic Beasts and Where to Find Them     7.5              234.02
# 11                           Hidden Figures     7.8              169.27
# 12                                Rogue One     7.9              532.17
# 13                                    Moana     7.7              248.75
# 14                                 Colossal     6.4                2.87

# %%
df.loc[:50, "Title"]
# Out:
# 0                         Guardians of the Galaxy
# 1                                      Prometheus
# 2                                           Split
# 3                                            Sing
# 4                                   Suicide Squad
# 5                                  The Great Wall
# 6                                      La La Land
# 7                                        Mindhorn
# 8                              The Lost City of Z
# 9                                      Passengers
# 10        Fantastic Beasts and Where to Find Them
# 11                                 Hidden Figures
# 12                                      Rogue One
# 13                                          Moana
# 14                                       Colossal
# 15                        The Secret Life of Pets
# 16                                  Hacksaw Ridge
# 17                                   Jason Bourne
# 18                                           Lion
# ...

# %%
df.Director.value_counts()
#identify the different categories in a feature as well as the count of values per category
# Out:
# Ridley Scott          8
# Michael Bay           6
# David Yates           6
# M. Night Shyamalan    6
# Paul W.S. Anderson    6
#                      ..
# Andrew Dominik        1
# Paul Verhoeven        1
# Andy Tennant          1
# Garth Davis           1
# Alessandro Carloni    1
# Name: Director, Length: 644, dtype: int64

# %%
df.iloc[:50, 3 : 7]
# Out:
#                                           Description              Director  \
# 0   A group of intergalactic criminals are forced ...            James Gunn
# 1   Following clues to the origin of mankind, a te...          Ridley Scott
# 2   Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3   In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4   A secret government agency recruits some of th...            David Ayer
# 5   European mercenaries searching for black powde...           Yimou Zhang
# 6   A jazz pianist falls for an aspiring actress i...       Damien Chazelle
# 7   A has-been actor best known for playing the ti...            Sean Foley
# 8   A true-life drama, centering on British explor...            James Gray
# 9   A spacecraft traveling to a distant colony pla...         Morten Tyldum
# 10  The adventures of writer Newt Scamander in New...           David Yates
# ...

# %%
df.iloc[:,7]
# Out:
# 0      121
# 1      124
# 2      117
# 3      108
# 4      123
#       ...
# 995    111
# 996     94
# 997     98
# 998     93
# 999     87
# Name: Runtime (Minutes), Length: 1000, dtype: int64

# %%
df.loc[:, "Director" : "Year"]
# Out:
#                  Director                                             Actors  \
# 0              James Gunn  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# 1            Ridley Scott  Noomi Rapace, Logan Marshall-Green, Michael Fa...
# 2      M. Night Shyamalan  James McAvoy, Anya Taylor-Joy, Haley Lu Richar...
# 3    Christophe Lourdelet  Matthew McConaughey,Reese Witherspoon, Seth Ma...
# 4              David Ayer  Will Smith, Jared Leto, Margot Robbie, Viola D...
# ..                    ...                                                ...
# 995             Billy Ray  Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...
# 996              Eli Roth  Lauren German, Heather Matarazzo, Bijou Philli...
# 997            Jon M. Chu  Robert Hoffman, Briana Evigan, Cassie Ventura,...
# 998        Scot Armstrong  Adam Pally, T.J. Miller, Thomas Middleditch,Sh...
# 999      Barry Sonnenfeld  Kevin Spacey, Jennifer Garner, Robbie Amell,Ch...
#
#      Year
# 0    2014
# 1    2012
# ...

# %% [markdown]
# # 5- Data Selection – Based on Conditional filtering

# %%
df.loc[(df["Rank"] >16), ["Rating", "Title", "Genre", "Director", "Year", "Rating", "Votes", "Revenue (Millions)"]]
# Out:
#      Rating                   Title                     Genre  \
# 16      8.2           Hacksaw Ridge   Biography,Drama,History
# 17      6.7            Jason Bourne           Action,Thriller
# 18      8.1                    Lion           Biography,Drama
# 19      8.0                 Arrival      Drama,Mystery,Sci-Fi
# 20      6.7                    Gold  Adventure,Drama,Thriller
# ..      ...                     ...                       ...
# 995     6.2    Secret in Their Eyes       Crime,Drama,Mystery
# 996     5.5         Hostel: Part II                    Horror
# 997     6.2  Step Up 2: The Streets       Drama,Music,Romance
# 998     5.6            Search Party          Adventure,Comedy
# 999     5.3              Nine Lives     Comedy,Family,Fantasy
#
#              Director  Year  Rating   Votes  Revenue (Millions)
# 16         Mel Gibson  2016     8.2  211760               67.12
# 17    Paul Greengrass  2016     6.7  150823              162.16
# ...

# %%
df[((df['Year'] >= 2009) & (df['Year'] <= 2016))
      & (df['Rating'] < 6.0)
      & (df['Revenue (Millions)'] > df['Revenue (Millions)'].quantile(0.95))]
# Out:
#      Rank                       Title                    Genre  \
# 941   942  The Twilight Saga: Eclipse  Adventure,Drama,Fantasy
#
#                                            Description     Director  \
# 941  As a string of mysterious killings grips Seatt...  David Slade
#
#                                                 Actors  Year  \
# 941  Kristen Stewart, Robert Pattinson, Taylor Laut...  2010
#
#      Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore
# 941                124     4.9  192740              300.52       58.0

# %% [markdown]
# # 6. Groupby operation

# %%
df.groupby(["Genre", "Year"])["Rating"].sum()
# Out:
# Genre                       Year
# Action                      2016    12.3
# Action,Adventure            2007     6.2
#                             2012     7.0
#                             2014     6.0
# Action,Adventure,Biography  2015     6.9
#                                     ...
# Sci-Fi,Thriller             2008     5.0
# Thriller                    2007     7.1
#                             2014     6.7
#                             2016    39.8
# Thriller,War                2016     6.0
# Name: Rating, Length: 583, dtype: float64

# %%
df.groupby(["Year"]).sum()
# Out:
#         Rank  Runtime (Minutes)  Rating     Votes  Revenue (Millions)  \
# Year
# 2006   25894               5317   313.5  11848758             3624.46
# 2007   30559               6446   378.1  12949545             4306.23
# 2008   32533               5763   352.8  14326280             5053.22
# 2009   29928               5922   355.0  13044813             5292.26
# 2010   35239               6668   409.6  15166939             5989.65
# 2011   37143               7220   430.8  15169789             5431.96
# 2012   34104               7623   443.2  18254470             6910.29
# 2013   50617              10562   619.9  19933518             7666.72
# 2014   50272              11220   670.1  19985162             7997.40
# 2015   62407              14541   838.5  14697230             8854.12
# 2016  111804              31890  1911.7  14431751            11211.65
#
#       Metascore
# Year
# 2006     2641.0
# 2007     2967.0
# 2008     2813.0
# 2009     2799.0
# 2010     3504.0
# ...

# %%
df.groupby('Director')[['Rating']].mean().head()
# Out:
#                      Rating
# Director
# Aamir Khan              8.5
# Abdellatif Kechiche     7.8
# Adam Leon               6.5
# Adam McKay              7.0
# Adam Shankman           6.3

# %%
df.groupby(["Title", "Year"])["Rating"].mean()
# Out:
# Title                 Year
# (500) Days of Summer  2009    7.7
# 10 Cloverfield Lane   2016    7.2
# 10 Years              2011    6.1
# 12 Years a Slave      2013    8.1
# 127 Hours             2010    7.6
#                              ...
# Zipper                2015    5.7
# Zodiac                2007    7.7
# Zombieland            2009    7.7
# Zoolander 2           2016    4.7
# Zootopia              2016    8.1
# Name: Rating, Length: 1000, dtype: float64

# %% [markdown]
# # 7- Sorting operation

# %%
df.sort_values("Metascore", ascending = False)
# Out:
#      Rank                 Title                      Genre  \
# 656   657               Boyhood                      Drama
# 41     42             Moonlight                      Drama
# 230   231       Pan's Labyrinth          Drama,Fantasy,War
# 111   112      12 Years a Slave    Biography,Drama,History
# 509   510               Gravity      Drama,Sci-Fi,Thriller
# ..    ...                   ...                        ...
# 967   968              The Walk  Adventure,Biography,Crime
# 969   970       The Lone Ranger   Action,Adventure,Western
# 971   972             Disturbia     Drama,Mystery,Thriller
# 989   990                 Selma    Biography,Drama,History
# 992   993  Take Me Home Tonight       Comedy,Drama,Romance
#
#                                            Description            Director  \
# 656  The life of Mason, from early childhood to his...   Richard Linklater
# 41   A chronicle of the childhood, adolescence and ...       Barry Jenkins
# ...

# %%
df.groupby('Director')[['Rating']].mean().sort_values(['Rating'], ascending=False).head(10)
# Out:
#                                   Rating
# Director
# Nitesh Tiwari                       8.80
# Christopher Nolan                   8.68
# Makoto Shinkai                      8.60
# Olivier Nakache                     8.60
# Florian Henckel von Donnersmarck    8.50
# Aamir Khan                          8.50
# Damien Chazelle                     8.40
# Naoko Yamada                        8.40
# Rajkumar Hirani                     8.30
# Lee Unkrich                         8.30

# %%
df.groupby('Title')[['Rating']].mean().sort_values(['Rating'], ascending=False).sample(5)
# Out:
#                         Rating
# Title
# Detour                     6.3
# The Amazing Spider-Man     7.0
# Gold                       6.7
# The Black Room             3.9
# Disturbia                  6.9

# %% [markdown]
# # 8. Dealing with missing values

# %%
df.isnull()
# Out:
#       Rank  Title  Genre  Description  Director  Actors   Year  \
# 0    False  False  False        False     False   False  False
# 1    False  False  False        False     False   False  False
# 2    False  False  False        False     False   False  False
# 3    False  False  False        False     False   False  False
# 4    False  False  False        False     False   False  False
# ..     ...    ...    ...          ...       ...     ...    ...
# 995  False  False  False        False     False   False  False
# 996  False  False  False        False     False   False  False
# 997  False  False  False        False     False   False  False
# 998  False  False  False        False     False   False  False
# 999  False  False  False        False     False   False  False
#
#      Runtime (Minutes)  Rating  Votes  Revenue (Millions)  Metascore
# 0                False   False  False               False      False
# 1                False   False  False               False      False
# ...

# %%
df.isnull().sum()
#df.isna().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %% [markdown]
# # Show where NAN value have in bar graph

# %%
from matplotlib import pyplot as plt
plt.figure(figsize = (7, 7))
df.isnull().sum().plot.bar(color = "g")
plt.title("NaN values")
plt.show()

# %% [markdown]
# # 9- Dropping columns and null values

# %%
df.dropna() #row missing
# Out:
#      Rank                     Title                     Genre  \
# 0       1   Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2                Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                     Split           Horror,Thriller
# 3       4                      Sing   Animation,Comedy,Family
# 4       5             Suicide Squad  Action,Adventure,Fantasy
# ..    ...                       ...                       ...
# 993   994  Resident Evil: Afterlife   Action,Adventure,Horror
# 994   995                 Project X                    Comedy
# 996   997           Hostel: Part II                    Horror
# 997   998    Step Up 2: The Streets       Drama,Music,Romance
# 999  1000                Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df.dropna(axis=1) #columnwise
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df.drop('Metascore', axis=1).head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
df.drop("Metascore", axis = 1, inplace = True)
df.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
df.dropna(axis=0, thresh=6)
#thresh parameter to specify the minimum number of non-null values for the column/row to be held without dropping
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %% [markdown]
# # 10. Apply( ) function:-
# The apply( ) function comes in handy when we want to apply any function to the dataset. It returns a value after passing each row of the dataframe to some function. The function can be built-in or user-defined.

# %%
def rating_group(rank):
    if rank >= 7.5:
        return 'Good'
    elif rank >= 6.0:
        return 'Average'
    else:
        return 'Bad'

# %%
df['Rating_category'] = df['Rank'].apply(rating_group)

# %%
df[['Title','Director','Rank','Rating_category']].head(7)
# Out:
#                      Title              Director  Rank Rating_category
# 0  Guardians of the Galaxy            James Gunn     1             Bad
# 1               Prometheus          Ridley Scott     2             Bad
# 2                    Split    M. Night Shyamalan     3             Bad
# 3                     Sing  Christophe Lourdelet     4             Bad
# 4            Suicide Squad            David Ayer     5             Bad
# 5           The Great Wall           Yimou Zhang     6         Average
# 6               La La Land       Damien Chazelle     7         Average

# %% [markdown]
# # THANK YOU
