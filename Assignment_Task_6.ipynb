# %% [markdown]
# # SUYASH PRATAP SINGH
#
#
# # Registration ID: GO_STP_6412

# %% [markdown]
# # 1- Load the necessary package for plotting using pyplot from matplotlib.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Days(x-axis) represents 8 days and Speed represents a car’s speed. Plot a Basic line plot between days and car speed, put x axis label as days and y axis label as car speed and put title Car Speed Measurement.
#
#          Days=[1,2,3,4,5,6,7,8]
#
#          Speed=[60,62,61,58,56,57,46,63]

# %% [markdown]
# # References:- https://matplotlib.org/stable/tutorials/text/annotations.html
#
# Annotate draws an arrow connecting two points in an axes.

# %%
mafia = np.array([1,2,3,4,5,6,7,8])   #mafia=days
tejas = np.array([60,62,61,58,56,57,46,63])  #tejas=speed

plt.figure(figsize=(10,6))
plt.plot(mafia,tejas,linewidth = 4,color='red',linestyle=':') #Changed line style, line color and line width

plt.xlabel('mafia')  #labelling the x-axis, y-axis and title
plt.ylabel('tejas')
plt.title('mafia tejas Measurement')

plt.annotate('start point', xy=(1, 60), xycoords='data',xytext=(30, -70),
textcoords='offset points',arrowprops=dict(arrowstyle= '<|-|>',
color='grey',lw=3.5,ls='--'),horizontalalignment='right', verticalalignment='bottom')  #starting point check

plt.annotate('low point', xy=(7, 46), xycoords='data',xytext=(35,80),
textcoords='offset points',arrowprops=dict(arrowstyle= '<|-|>',
color='grey',lw=3.5,ls='--'),horizontalalignment='right', verticalalignment='bottom') #low point check

plt.annotate('end point', xy=(8, 63), xycoords='data',xytext=(25, -80),
textcoords='offset points',arrowprops=dict(arrowstyle= '<|-|>',
color='grey',lw=3.5,ls='--'),horizontalalignment='right', verticalalignment='bottom') #end point check

plt.show()

# %% [markdown]
# # 2- Now to above car data apply some string formats  like line style example green dotted line, marker shape like +, change markersize, markerface color etc.

# %%
plt.figure(figsize=(10,6))
plt.plot(mafia,tejas,linewidth = 4,color='green',linestyle=':') #Changed line style, line color and line width

plt.xlabel('mafia')  #labelling the x-axis, y-axis and title
plt.ylabel('tejas')
plt.title('mafia tejas Measurement')

plt.scatter(mafia,tejas,s=110,marker='+',c = 'r') # Changed marker size and markerface color

plt.annotate('start point', xy=(1, 60), xycoords='data',xytext=(30, -70),
textcoords='offset points',arrowprops=dict(arrowstyle= '<|-|>',
color='grey',lw=3.5,ls='--'),horizontalalignment='right', verticalalignment='bottom')  #starting point check

plt.annotate('low point', xy=(7, 46), xycoords='data',xytext=(35,80),
textcoords='offset points',arrowprops=dict(arrowstyle= '<|-|>',
color='grey',lw=3.5,ls='--'),horizontalalignment='right', verticalalignment='bottom') #low point check

plt.annotate('end point', xy=(8, 63), xycoords='data',xytext=(25, -80),
textcoords='offset points',arrowprops=dict(arrowstyle= '<|-|>',
color='grey',lw=3.5,ls='--'),horizontalalignment='right', verticalalignment='bottom') #end point check

plt.show()

# %% [markdown]
# # # 2-Method:-

# %%
plt.plot([1,2,3,4,5,6,7,8],'go-')
plt.plot([60,62,61,58,56,57,46,63],'-b+',linewidth=2, markersize=10)
plt.xlabel('mafia') #mafia = days
plt.ylabel('tejas') #speed = tejas
plt.title('mafia tejas Measurement')
plt.show()

# %% [markdown]
# # 3- Plot Axes Labels, Chart title, Legend, Grid in Car minimum, Maximum and average speed in 8 days.
#
# days=[1,2,3,4,5,6,7,8]
#
# max_speed=[80,91,92,88,77,79,76,75]
#
# min_speed=[42,43,40,42,33,36,34,35]
#
# avg_speed=[46,58,57,56,40,42,41,36]

# %%
mafia1=[1,2,3,4,5,6,7,8]

maxi=[80,91,92,88,77,79,76,75]

mini=[42,43,40,42,33,36,34,35]

avg=[46,58,57,56,40,42,41,36]


plt.plot(mafia1, maxi, "r", label = "Maxi Speed")

plt.plot(mafia1, mini, "g", label = "Mini Speed")

plt.plot(mafia1, avg, "b", label = "Avg Speed")

plt.title("mafia1 tejas Measurement")  #labelling of title

plt.xlabel("mafia1") #labelling of x-axis

plt.ylabel("tejas ") #labelling of y-axis

plt.legend() #showing legends

plt.grid() #showing grid

plt.show()

# %% [markdown]
# # 4-  Plotting a basic sine graph by adding more features. Adding Multiple plots by Superimposition like cosine wave.

# %%
x = np.linspace(0,5,90)  #start,stop,step
y = np.sin(x)
z = np.cos(x)
plt.figure(figsize=(10,6))
plt.plot(x,y,':g', linewidth = 3)
plt.plot(x,z,'--r',linewidth = 3)
plt.xlabel("tejas")
plt.ylabel("kp")
plt.title("tejas/kp function curve")
plt.legend(['sine','cosine']) # legend entries as seperate strings in a list
plt.show()

# %%
x = np.arange(0,4*np.pi-1,0.1)   # start,stop,step
y = np.sin(x)
z = np.cos(x)
plt.plot(x,y,x,z)
plt.xlabel("tejas")
plt.ylabel("kp")
plt.title("tejas/kp function curve")
plt.legend(['sine','cosine']) # legend entries as seperate strings in a list
plt.show()

# %% [markdown]
# # 5-  Plot Simple bar chart showing popularity of Programming Languages.
#
# Languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
#
# Popularity = [56, 39, 34, 34, 29]
#
# Security = [44 ,36 ,55, 50, 42]
#
# Plot Multiple Bars showing Popularity and Security of major Programming Languages. Also Create Horizontal bar chart using barh function.

# %%
plt.barh(56, 44, label='Python', color=(0.4, 0.6, 0.8, 1.0), edgecolor='blue')
plt.barh(39, 36, label='SQL', color='r', edgecolor='red')
plt.barh(34, 55, label='Java', color='y', edgecolor='blue')
plt.barh(34, 50, label='C++', color='c', edgecolor='blue')
plt.barh(29, 42, label='JavaScript', color='m', edgecolor='blue')
plt.legend()
plt.grid()
plt.xlabel("vineet")  #vineet= popularity
plt.ylabel("kp")  #kp= security
plt.title("vineet of Programming Language\n")
plt.show()

# %%
suyash =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
vineet = [56, 39, 34, 34, 29]
plt.barh(suyash, vineet, color = "g", label = "vineet")
plt.legend()
plt.show()

# %% [markdown]
# # 6- Plot Histogram, We have a sample data of Students marks of various Students, we will try to plot number of Students by marks range and try to figure out how many Students are average, below-average and Excellent.
#
# Marks = [ 61,86,42,46,73,95,65,78,53,92,55,69,70,49,72,86,64]
#
# Histogram showing Below Average, Average and Execellent distribution
#
# 40-60: Below Average
#
# 60-80: Average
#
# 80-100: Excellent

# %%
Marks = np.array([61,86,42,46,73,95,65,78,53,92,55,69,70,49,72,86,64])

below_avg = Marks[np.logical_and(Marks >= 40,Marks < 60)]

avg = Marks[np.logical_and(Marks >= 60,Marks < 80)]

excell = Marks[np.logical_and(Marks >= 80,Marks < 100)]

# %%
print(f'No of Below Average students : {below_avg.size}')

print(f'No of Average students : {avg.size}')

print(f'No of Excellent students : {excell.size}')
# Out:
# No of Below Average students : 5
# No of Average students : 8
# No of Excellent students : 4

# %%
plt.figure(figsize=(12,6))
plt.hist(Marks, bins = [40, 60, 80,100], align='right', color='lightblue', edgecolor='black')
plt.xlabel('vineet')
plt.ylabel('tejas')
plt.title('Histogram of tejas Marks')
plt.show()

# %% [markdown]
# # Titanic Data Set Download Data
#
#  Load the data file
#
#  (i) Create a pie chart presenting the male/female proportion
#
#  (ii) Create a scatterplot with the Fare paid and the Age, differ the plot color by gender

# %%
import seaborn as sns
teju = sns.load_dataset('titanic')

# %%
teju.sample(5) #random print five row
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 255         1       3  female  29.0      0      2  15.2458        C   Third
# 543         1       2    male  32.0      1      0  26.0000        S  Second
# 463         0       2    male  48.0      0      0  13.0000        S  Second
# 293         0       3  female  24.0      0      0   8.8500        S   Third
# 120         0       2    male  21.0      2      0  73.5000        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# 255  woman       False  NaN    Cherbourg   yes  False
# 543    man        True  NaN  Southampton   yes  False
# 463    man        True  NaN  Southampton    no   True
# 293  woman       False  NaN  Southampton    no   True
# 120    man        True  NaN  Southampton    no  False

# %%
teju.head(4) #print first four row
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False

# %%
teju.nunique()
# Out:
# survived         2
# pclass           3
# sex              2
# age             88
# sibsp            7
# parch            7
# fare           248
# embarked         3
# class            3
# who              3
# adult_male       2
# deck             7
# embark_town      3
# alive            2
# alone            2
# dtype: int64

# %%
plt.figure(figsize=(8,8))
vin = teju.sex.value_counts()
plt.pie(vin, labels = ["Male", "Female"], shadow = True, autopct = "%0.0f%%")
plt.title("male / female Proportion")
plt.show()

# %%
tej = teju[teju["sex"] == "male"]

# %%
surbhi = teju[teju["sex"] == "female"]

# %%
plt.figure(figsize=(12,6))

plt.scatter(tej.fare,tej.age,label='Male',color='blue',marker='*')

plt.scatter(surbhi.fare,surbhi.age,label='Female',color='red',marker='+')

plt.xlabel('Fare')

plt.ylabel('Age')

plt.title('Scatter Plot')
plt.legend()
plt.show()

# %% [markdown]
# # THANK YOU
